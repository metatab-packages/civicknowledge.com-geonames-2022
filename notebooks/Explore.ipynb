# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Geographical Region Names
# `civicknowledge.com-geonames-2022-1.1.1` Last Update: 2023-02-21T00:00:17
#
# _Country names, and names for US countries, metros, cities and states._
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [names](data/names.csv)**. Geographic names
#
# ## References
# <ul><li> <strong><a href="https://datahub.io/core/country-codes/r/country-codes.csv">country_codes</a></strong>. Country codes, from https://datahub.io/core/country-codes</li><li> <strong>states</string>, <em>censusgeo://2022/5/US/state</em>. </li><li> <strong>metros</string>, <em>censusgeo://2020/5/US/CBSA</em>. </li><li> <strong>counties</string>, <em>censusgeo://2022/5/US/county</em>. </li><li> <strong>places</string>, <em>censusgeo://2020/5/{}/place</em>. </li><ul>

# %%
pkg.resource('names').dataframe()
# Out:
#                    ref      geoid            name          name2 category
# 0      geoid:04000US54  04000US54   West Virginia  West Virginia    state
# 1      geoid:04000US54  04000US54         Florida        Florida    state
# 2      geoid:04000US54  04000US54        Illinois       Illinois    state
# 3      geoid:04000US54  04000US54       Minnesota      Minnesota    state
# 4      geoid:04000US54  04000US54        Maryland       Maryland    state
# ...                ...        ...             ...            ...      ...
# 36384     ISO3166:0732        NaN  Western Sahara            ESH  country
# 36385     ISO3166:0887        NaN           Yemen            YEM  country
# 36386     ISO3166:0894        NaN          Zambia            ZMB  country
# 36387     ISO3166:0716        NaN        Zimbabwe            ZWE  country
# 36388     ISO3166:0248        NaN   Åland Islands            ALA  country
#
# [36389 rows x 5 columns]
