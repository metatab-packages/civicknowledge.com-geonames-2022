# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import rowgenerators as rg
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Geographical Region Names
# `civicknowledge.com-geonames-2022-1.1.1` Last Update: 2023-02-20T21:04:26
#
# _Country names, and names for US countries, metros, cities and states._
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
#
# ## References
# <ul><li> <strong><a href="https://datahub.io/core/country-codes/r/country-codes.csv">country_codes</a></strong>. Country codes, from https://datahub.io/core/country-codes</li><li> <strong>states</string>, <em>censusgeo://2022/5/US/state</em>. </li><li> <strong>metros</string>, <em>censusgeo://2020/5/US/CBSA</em>. </li><li> <strong>counties</string>, <em>censusgeo://2022/5/US/county</em>. </li><li> <strong>places</string>, <em>censusgeo://2020/5/{}/place</em>. </li><ul>

# %%
cc = pkg.reference('country_codes').dataframe()
cc = cc[['ISO3166-1-Alpha-3', 'ISO3166-1-Alpha-2','ISO3166-1-numeric', 'CLDR display name']]
cc.columns = ['country_3', 'country_2', 'numeric', 'country_name']
cc['numeric'] = cc.numeric.astype('Int64')


cc.head()
# Out:
#   country_3 country_2  numeric    country_name
# 0       TWN        TW      158          Taiwan
# 1       AFG        AF        4     Afghanistan
# 2       ALB        AL        8         Albania
# 3       DZA        DZ       12         Algeria
# 4       ASM        AS       16  American Samoa

# %%
countries = pd.DataFrame({
    'ref': "ISO3166:"+cc.numeric.astype(str).str.zfill(4),
    'geoid': None, 
    'name': cc.country_name,
    'name2': cc.country_3, 
    'category': 'country'
})
    
countries.head()
# Out:
#             ref geoid            name name2 category
# 0  ISO3166:0158  None          Taiwan   TWN  country
# 1  ISO3166:0004  None     Afghanistan   AFG  country
# 2  ISO3166:0008  None         Albania   ALB  country
# 3  ISO3166:0012  None         Algeria   DZA  country
# 4  ISO3166:0016  None  American Samoa   ASM  country

# %%
states = pkg.reference('states').dataframe()
cbsa = pkg.reference('metros').dataframe()
counties = pkg.reference('counties').dataframe()

# %%
from tqdm.auto import tqdm

def foreach_state(url):
    
    minor_outlying_areas = ['VI', 'MP', 'GU', 'AS'] # Virgin Islands, Guam, etc. 
    
    frames = []
    errors = []
    for idx, r in tqdm(list(states.iterrows())):
        
        if r.STUSPS in minor_outlying_areas:
            continue
        
        try:
            frames.append(rg.dataframe(url.format(r.STUSPS)))
        except Exception as e:
            errors.append((e, r.STUSPS))
            
    return pd.concat(frames), errors

places, place_errors = foreach_state(pkg.reference('places').value)
     
print(len(place_errors))
places.head()
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]
# 0
#   STATEFP PLACEFP   PLACENS    GEOID           NAME            NAMELSAD LSAD  \
# 0      54   52060  02390615  5452060    Martinsburg    Martinsburg city   25
# 1      54   08092  02390733  5408092    Blacksville    Blacksville town   43
# 2      54   76516  02391427  5476516      Star City      Star City town   43
# 3      54   40828  02391244  5440828       Jane Lew       Jane Lew town   43
# 4      54   35284  02390232  5435284  Harpers Ferry  Harpers Ferry town   43
#
#   CLASSFP PCICBSA PCINECTA  MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT  \
# 0      C1       Y        N  G4110        A  17173918   42877  +39.4577694
# 1      C1       N        N  G4110        A    775505   24048  +39.7156423
# 2      C1       N        N  G4110        A   1265921  261961  +39.6591556
# 3      C1       N        N  G4110        A    618089   18635  +39.1107834
# 4      C1       N        N  G4110        A   1386068  229271  +39.3252427
#
#        INTPTLON                                           geometry
# 0  -077.9782123  POLYGON ((-78.02431 39.44383, -78.02271 39.447...
# 1  -080.2147110  POLYGON ((-80.22155 39.72121, -80.22151 39.721...
# 2  -079.9866248  POLYGON ((-79.99425 39.65447, -79.99423 39.654...
# 3  -080.4080091  POLYGON ((-80.41503 39.11067, -80.41414 39.111...
# 4  -077.7414418  POLYGON ((-77.75475 39.32983, -77.75474 39.329...

# %%
from geoid.tiger import State, Cbsa, County, Place

# %%
from geoid.tiger import TigerGeoid

frames = []
for e, gc, cat in ( (states, State, 'state'), (cbsa, Cbsa, 'metro'), (counties, County, 'county'), (places, Place,'place')):
    
    
    name2 = e['NAMELSAD'] if 'NAMELSAD' in e.columns else e['NAME']
    geoid =  str(gc.parse(e.iloc[0].GEOID).as_acs())
    
    frames.append(pd.DataFrame(dict(ref='geoid:'+geoid, geoid=geoid, name=e.NAME, name2=name2, category=cat)))
    
names = pd.concat(frames+[countries])
names.sample(20)
# Out:
#                        ref           geoid                 name  \
# 408   geoid:16000US5452060  16000US5452060                Lamar
# 321   geoid:16000US5452060  16000US5452060               Mesita
# 238   geoid:16000US5452060  16000US5452060           Arthurdale
# 759   geoid:16000US5452060  16000US5452060        Pelican Marsh
# 812     geoid:05000US31039    05000US31039               Norman
# 2081    geoid:05000US31039    05000US31039              Lowndes
# 214   geoid:16000US5452060  16000US5452060                 Tony
# 2310    geoid:05000US31039    05000US31039               Yadkin
# 385   geoid:16000US5452060  16000US5452060              Langley
# 42    geoid:16000US5452060  16000US5452060             St. John
# 357   geoid:16000US5452060  16000US5452060          Bridgeville
# 1400  geoid:16000US5452060  16000US5452060  Kutztown University
# 75    geoid:16000US5452060  16000US5452060        Port Townsend
# 558   geoid:16000US5452060  16000US5452060                  Ney
# 757   geoid:16000US5452060  16000US5452060        East Shoreham
# 540   geoid:16000US5452060  16000US5452060            Ashtabula
# 2785    geoid:05000US31039    05000US31039               McLean
# 701   geoid:16000US5452060  16000US5452060         Murraysville
# 205   geoid:16000US5452060  16000US5452060             Patillas
# 20    geoid:16000US5452060  16000US5452060      Amargosa Valley
#
#                         name2 category
# 408             Lamar village    place
# 321                Mesita CDP    place
# 238            Arthurdale CDP    place
# 759         Pelican Marsh CDP    place
# 812             Norman County   county
# 2081           Lowndes County   county
# 214              Tony village    place
# 2310            Yadkin County   county
# 385               Langley CDP    place
# 42              St. John city    place
# 357           Bridgeville CDP    place
# 1400  Kutztown University CDP    place
# 75         Port Townsend city    place
# 558               Ney village    place
# 757         East Shoreham CDP    place
# 540            Ashtabula city    place
# 2785            McLean County   county
# 701          Murraysville CDP    place
# 205      Patillas zona urbana    place
# 20        Amargosa Valley CDP    place
