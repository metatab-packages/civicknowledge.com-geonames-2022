# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import rowgenerators as rg
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Geographical Region Names
# `civicknowledge.com-geonames-2022-1.1.1` Last Update: 2023-02-19T00:36:11
#
# __
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
#
# ## References
# <ul><li> <strong><a href="https://datahub.io/core/country-codes/r/country-codes.csv">country_codes</a></strong>. Country codes, from https://datahub.io/core/country-codes</li><ul>

# %%
cc = pkg.reference('country_codes').dataframe()
cc = cc[['ISO3166-1-Alpha-3', 'ISO3166-1-Alpha-2','ISO3166-1-numeric', 'CLDR display name']]
cc.columns = ['country_3', 'country_2', 'numeric', 'country_name']
cc['numeric'] = cc.numeric.astype('Int64')

# In US Census geocode, summary level 10 is for the whole US, but the country code is always 'US', so 

# we will just re-use that for the geoid for countries. 


cc.head()
# Out:
#   country_3 country_2  numeric    country_name
# 0       TWN        TW      158          Taiwan
# 1       AFG        AF        4     Afghanistan
# 2       ALB        AL        8         Albania
# 3       DZA        DZ       12         Algeria
# 4       ASM        AS       16  American Samoa

# %%
countries = pd.DataFrame({
    'geoid': '01000'+cc.country_2,
    'name': cc.country_name,
    'name2': cc.country_3, 
    'category': 'country'
})
    
countries.head()
# Out:
#      geoid            name name2 category
# 0  01000TW          Taiwan   TWN  country
# 1  01000AF     Afghanistan   AFG  country
# 2  01000AL         Albania   ALB  country
# 3  01000DZ         Algeria   DZA  country
# 4  01000AS  American Samoa   ASM  country

# %%
states =rg.dataframe('censusgeo://2022/5/US/state')
cbsa =rg.dataframe('censusgeo://2020/5/US/CBSA')
counties = rg.dataframe('censusgeo://2022/5/US/county')

# %%
from tqdm.auto import tqdm

def foreach_state(url):
    
    minor_outlying_areas = ['VI', 'MP', 'GU', 'AS'] # Virgin Islands, Guam, etc. 
    
    frames = []
    errors = []
    for idx, r in tqdm(list(states.iterrows())):
        
        if r.STUSPS in minor_outlying_areas:
            continue
        
        try:
            frames.append(rg.dataframe(url.format(r.STUSPS)))
        except Exception as e:
            errors.append((e, r.STUSPS))
            
    return pd.concat(frames), errors

places, place_errors = foreach_state('censusgeo://2020/5/{}/place')
     
print(len(place_errors))
places.head()
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]
# 0
#   STATEFP PLACEFP   PLACENS    GEOID           NAME            NAMELSAD LSAD  \
# 0      54   52060  02390615  5452060    Martinsburg    Martinsburg city   25
# 1      54   08092  02390733  5408092    Blacksville    Blacksville town   43
# 2      54   76516  02391427  5476516      Star City      Star City town   43
# 3      54   40828  02391244  5440828       Jane Lew       Jane Lew town   43
# 4      54   35284  02390232  5435284  Harpers Ferry  Harpers Ferry town   43
#
#   CLASSFP PCICBSA PCINECTA  MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT  \
# 0      C1       Y        N  G4110        A  17173918   42877  +39.4577694
# 1      C1       N        N  G4110        A    775505   24048  +39.7156423
# 2      C1       N        N  G4110        A   1265921  261961  +39.6591556
# 3      C1       N        N  G4110        A    618089   18635  +39.1107834
# 4      C1       N        N  G4110        A   1386068  229271  +39.3252427
#
#        INTPTLON                                           geometry
# 0  -077.9782123  POLYGON ((-78.02431 39.44383, -78.02271 39.447...
# 1  -080.2147110  POLYGON ((-80.22155 39.72121, -80.22151 39.721...
# 2  -079.9866248  POLYGON ((-79.99425 39.65447, -79.99423 39.654...
# 3  -080.4080091  POLYGON ((-80.41503 39.11067, -80.41414 39.111...
# 4  -077.7414418  POLYGON ((-77.75475 39.32983, -77.75474 39.329...

# %%
from geoid.tiger import State, Cbsa, County, Place

# %%
from geoid.tiger import TigerGeoid

frames = []
for e, gc, cat in ( (states, State, 'state'), (cbsa, Cbsa, 'metro'), (counties, County, 'county'), (places, Place,'place')):
    
    
    name2 = e['NAMELSAD'] if 'NAMELSAD' in e.columns else e['NAME']
    geoid =  str(gc.parse(e.iloc[0].GEOID).as_acs())
    
    frames.append(pd.DataFrame(dict(geoid=geoid, name=e.NAME, name2=name2, category=cat)))
    
names = pd.concat(frames+[countries])
names.sample(20)
# Out:
#                geoid                    name                        name2  \
# 488   16000US5452060               Northwood               Northwood city
# 107   16000US5452060                Lordship                 Lordship CDP
# 1283  16000US5452060                Brighton             Brighton village
# 35    16000US5452060               Riverdale               Riverdale city
# 638   16000US5452060                  Putney                   Putney CDP
# 180   16000US5452060                Woodward                Woodward city
# 11    16000US5452060                Staunton                Staunton city
# 246   16000US5452060              Woods Hole               Woods Hole CDP
# 842   16000US5452060              Hackensack              Hackensack city
# 115   16000US5452060                Hamilton                Hamilton town
# 423   16000US5452060         St. Clairsville      St. Clairsville borough
# 2820    05000US31039                   Grant                 Grant County
# 224   16000US5452060                Gu Oidak                 Gu Oidak CDP
# 686   16000US5452060                Herbster                 Herbster CDP
# 220   16000US5452060              Greasewood               Greasewood CDP
# 95           01000GT               Guatemala                          GTM
# 335   16000US5452060                  Baxter                  Baxter town
# 447   16000US5452060  Rancho Santa Margarita  Rancho Santa Margarita city
# 2300    05000US31039                    Iowa                  Iowa County
# 329   16000US5452060                    Edom                    Edom city
#
#      category
# 488     place
# 107     place
# 1283    place
# 35      place
# 638     place
# 180     place
# 11      place
# 246     place
# 842     place
# 115     place
# 423     place
# 2820   county
# 224     place
# 686     place
# 220     place
# 95    country
# 335     place
# 447     place
# 2300   county
# 329     place
